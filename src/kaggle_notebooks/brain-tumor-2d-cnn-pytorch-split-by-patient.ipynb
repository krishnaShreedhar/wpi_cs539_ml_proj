# %% [markdown]
# **Note**: network architecture and original data split strategy are based on [this noteboook](https://www.kaggle.com/mmellinger66/brain-tumor-basic-tensorflow-model).
#
# In this notebook, I want to demonstrate the importance of splitting data properly, especially when using 2d cnn where each data point is a slice. If we split the data normally, the validation AUC can be deceptively high because similar slices of the same patient can appear in both train and validation set. Thus we should split the data based on patient id. Here are some noteable changes I made compared to the original notebook:
# 1. Use split-by-patient strategy on top of their original split strategy (I called it holdout sets in this notebook)
# 2. Reimplement using pytorch
# 3. Prediction for a patient is the average of slices probabilities (instead of the average of slices 0-1 predictions in the original notebook)
# 4. Track both patient AUC and slice AUC when training
# 5. Calculate out-of-fold AUC and average AUC across all folds to get a more reliable result
# 6. Remove the result rounding part because I didn't find it meaningful

# %%
import sys
sys.path.append('../input/monai-v070')

# %%
import os
import cv2
import glob
import pydicom
import random
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm
import time
import datetime
from dataclasses import dataclass, field
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score
from copy import deepcopy

from monai.data import CacheDataset, DataLoader
from monai.transforms import *

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_everything(42)

class AverageMeter:
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
DATA_DIR = '../input/rsna-miccai-brain-tumor-radiogenomic-classification/'
MRI_TYPES = ["FLAIR", "T1w", "T2w", "T1wCE"]

# %% [markdown]
# ## Dataset

# %%
class BrainTumorDataset(CacheDataset):
    def __init__(self, root_dir, patient_ids, mri_types, annotations, section, *args, **kwargs):
        self.root_dir = root_dir
        self.patient_ids = patient_ids
        self.mri_types = mri_types
        self.annotations = annotations
        data = self.get_data()
        if section is not None:
            train_data, val_data = train_test_split(data, test_size=0.2, random_state=42)
            data = train_data if section=='train' else val_data
        super(BrainTumorDataset, self).__init__(data, *args, **kwargs)
    
    def get_data(self):
        data = []
        for patient_id in tqdm(self.patient_ids):
            if self.annotations is not None:
                label = self.annotations[self.annotations['BraTS21ID'] 
                                         == int(patient_id)]['MGMT_value'].item()
            else:
                label = 0 # dummy value
            for slice_path in self.get_patient_slice_paths(patient_id):
                data.append({
                    'image': slice_path,
                    'label': label,
                    'patient_id': patient_id
                })
        return data
    
    def get_patient_slice_paths(self, patient_id):
        '''
        Returns an array of all the images of a particular type for a particular patient ID
        '''
        assert(set(self.mri_types) <= set(MRI_TYPES))
        patient_path = os.path.join(self.root_dir, str(patient_id).zfill(5))
        patient_slice_paths = []
        for mri_type in self.mri_types:
            paths = sorted(
                glob.glob(os.path.join(patient_path, mri_type, "*.dcm")), 
                key=lambda x: int(x[:-4].split("-")[-1]),
            )

            num_images = len(paths)
            start = int(num_images * 0.25)
            end = int(num_images * 0.75)

            interval = 3
            if num_images < 10: 
                interval = 1
            patient_slice_paths.extend(paths[start:end:interval])
        return patient_slice_paths
    
class LoadDicomd(MapTransform):
    def __init__(self, img_size, *args, **kwargs):
        self.img_size = img_size
        super(LoadDicomd, self).__init__(*args, **kwargs)
    
    def __call__(self, data):
        d = dict(data)
        for key in self.keys:
            d[key] = self.load_dicom(d[key])
        return d

    def load_dicom(self, path):
        ''' 
        Reads a DICOM image, standardizes so that the pixel values are between 0 and 1, 
        then rescales to 0 and 255
        '''
        dicom = pydicom.read_file(path)
        data = dicom.pixel_array
        if np.max(data) != 0:
            data = data / np.max(data)
        data = (data * 255).astype(np.uint8)
        data = cv2.resize(data, (self.img_size, self.img_size)) / 255
        return np.expand_dims(data, axis=0)

# %% [markdown]
# ## Model

# %%
class Simple2dCNN(nn.Module):
    def __init__(self, 
                 input_channels=1, 
                 n_classes=2, 
                 img_size=32, 
                 conv1_filters=128,
                 conv2_filters=64,
                 dropout_prob=0.1,
                 fc1_units=48):
        super(Simple2dCNN, self).__init__()
        
        self.relu = nn.ReLU()
        
        self.conv1 = nn.Conv2d(input_channels, conv1_filters, 4)
        self.maxpool1 = nn.MaxPool2d(2)
        
        self.conv2 = nn.Conv2d(conv1_filters, conv2_filters, 2)
        self.maxpool2 = nn.MaxPool2d(1)
        
        self.dropout = nn.Dropout(dropout_prob)
        last_feature_map_size = (img_size - 3) // 2 - 1
        self.fc1 = nn.Linear(conv2_filters * last_feature_map_size**2, fc1_units)
        self.fc2 = nn.Linear(fc1_units, n_classes)

    def forward(self, x):
        # (None, 1, 32, 32)
        x = self.relu(self.conv1(x)) # (None, 128, 29, 29)
        x = self.maxpool1(x) # (None, 128, 14, 14)
        
        x = self.relu(self.conv2(x)) # (None, 64, 13, 13)
        x = self.maxpool2(x) # (None, 64, 13, 13)
        
        x = self.dropout(x)
        x = x.view(x.size(0), -1) # (None, 64 * 13 * 13)
        x = self.relu(self.fc1(x)) # (None, 48)
        x = self.fc2(x) # (None, 2)
        return x

# %% [markdown]
# ## Pipeline

# %%
@dataclass
class Config:
    train_dir: str = os.path.join(DATA_DIR, 'train')
    test_dir: str = os.path.join(DATA_DIR, 'test')
    annotation_path: str = os.path.join(DATA_DIR, 'train_labels.csv')
    n_classes: int = 2
    img_size: int = 32
    n_workers: int = 4
    early_stopping_rounds: int = 3
    n_folds: int = 5
        
        
class Pipeline:
    def __init__(self, config):
        self.args = config
        self.device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')
        self.annotations = None
        self.model = None
        self.load_model()
        # transforms
        self.preaugment_transform = [
            LoadDicomd(keys="image", img_size=self.args.img_size),
        ]
        self.augment_transform = [] # todo: add some augmentations
        self.postaugment_transform = [
            ToTensord(keys="image", dtype=torch.float),
            ToTensord(keys="label", dtype=torch.int64),
        ]
        
    def load_annotations(self):
        self.annotations = pd.read_csv(self.args.annotation_path)
        # exclude 3 cases
        self.annotations = self.annotations[~self.annotations['BraTS21ID'].isin([109, 123, 709])]
        self.annotations = self.annotations.reset_index(drop=True)
        skf = StratifiedKFold(n_splits=self.args.n_folds, shuffle=True, random_state=42)
        # split by patient, stratify based on target value
        folds = skf.split(self.annotations['BraTS21ID'].values, self.annotations['MGMT_value'].values)
        for i, (train_indices, val_indices) in enumerate(folds):
            self.annotations.loc[val_indices, 'fold'] = i
        self.annotations['fold'] = self.annotations['fold'].astype(int)
    
    def load_model(self, weights_path=None):
        self.model = Simple2dCNN(input_channels=1, 
                                 n_classes=self.args.n_classes,
                                 img_size=self.args.img_size).to(self.device)
        if weights_path:
            weights = torch.load(weights_path, map_location=self.device)
            self.model.load_state_dict(weights)
        
    def prepare_datasets(self, mri_types, fold, cache_rate):
        """
        Data format:
        {
            'image': torch tensor (batch_size, 1, 32, 32),
            'label': torch tensor (batch_size, )
            'patient_id'
        }
        Output: torch tensor (batch_size, 2)
        """
        train_transform = Compose(
            self.preaugment_transform +
            self.augment_transform +
            self.postaugment_transform
        )
        val_transform = Compose(
            self.preaugment_transform +
            self.postaugment_transform
        )
        
        train_ids = self.annotations[self.annotations['fold']!=fold]['BraTS21ID'].values.tolist()
        val_holdout_ids = self.annotations[self.annotations['fold']==fold]['BraTS21ID'].values.tolist()
        
        train_ds = BrainTumorDataset(root_dir=self.args.train_dir, 
                                     patient_ids=train_ids, 
                                     mri_types=mri_types,  
                                     annotations=self.annotations,
                                     transform=train_transform,
                                     section='train',
                                     cache_rate=cache_rate,
                                     num_workers=self.args.n_workers)
        val_ds = BrainTumorDataset(root_dir=self.args.train_dir, 
                                   patient_ids=train_ids, 
                                   mri_types=mri_types,  
                                   annotations=self.annotations,
                                   transform=val_transform,
                                   section='val',
                                   cache_rate=cache_rate,
                                   num_workers=self.args.n_workers)
        val_holdout_ds = BrainTumorDataset(root_dir=self.args.train_dir, 
                                           patient_ids=val_holdout_ids, 
                                           mri_types=mri_types, 
                                           annotations=self.annotations, 
                                           transform=val_transform,
                                           section=None,
                                           cache_rate=cache_rate,
                                           num_workers=self.args.n_workers)
        return train_ds, val_ds, val_holdout_ds
    
    def prepare_test_dataset(self, mri_types, cache_rate):
        test_transform = Compose(
            self.preaugment_transform +
            self.postaugment_transform
        )
        test_ids = [int(patient_id) for patient_id in os.listdir(self.args.test_dir)]
        test_ids = sorted(test_ids, key=lambda x: int(x))
        test_ds = BrainTumorDataset(root_dir=self.args.test_dir, 
                                    patient_ids=test_ids, 
                                    mri_types=mri_types, 
                                    annotations=None, 
                                    transform=test_transform,
                                    section=None,
                                    cache_rate=cache_rate,
                                    num_workers=self.args.n_workers)
        return test_ds
    
    def train_epoch(self, loader, loss_function, optimizer, verbose):
        self.model.train()
        summary_loss = AverageMeter()
        start = time.time()
        n = len(loader)
        for step, batch_data in enumerate(loader):
            inputs, labels = (
                batch_data["image"].to(self.device), # (None, 1, 32, 32)
                batch_data["label"].to(self.device), # (None, )
            )
            batch_size = inputs.size(0)
            # back propagation
            optimizer.zero_grad()
            outputs = self.model(inputs) # (None, 2)
            loss = loss_function(outputs, labels)
            loss.backward()
            optimizer.step()
            # update stats
            summary_loss.update(loss.item(), batch_size)
            if verbose:
                print('Train step {}/{}, loss: {:.5f}'.format(step + 1, n, 
                                                              summary_loss.avg), end='\r')
        elapsed_time = str(datetime.timedelta(seconds=time.time() - start))
        print('Train loss: {:.5f} - time: {}'.format(summary_loss.avg, elapsed_time))
        return summary_loss.avg
    
    def evaluate_epoch(self, loader, loss_function, verbose):
        self.model.eval()
        summary_loss = AverageMeter()
        start = time.time()
        n = len(loader)
        patient_ids_all = []
        probabilities_all = []
        labels_all = []
        with torch.no_grad():
            for step, batch_data in enumerate(loader):
                inputs, labels, patient_ids = (
                    batch_data["image"].to(self.device), # (None, 1, 32, 32)
                    batch_data["label"].to(self.device), # (None, )
                    batch_data["patient_id"], # (None, )
                )
                batch_size = inputs.size(0)
                # back propagation
                outputs = self.model(inputs) # (None, 2)
                loss = loss_function(outputs, labels)
                # update stats
                probabilities = F.softmax(outputs, dim=1)[:, 1].tolist()
                probabilities_all.extend(probabilities)
                labels_all.extend(labels.tolist())
                patient_ids_all.extend(patient_ids)
                
                summary_loss.update(loss.item(), batch_size)
                if verbose:
                    print('Val step {}/{}, loss: {:.5f}'.format(step + 1, n, 
                                                                summary_loss.avg), end='\r')
        elapsed_time = str(datetime.timedelta(seconds=time.time() - start))
        print('Val loss: {:.5f} - time: {}'.format(summary_loss.avg, elapsed_time))
        result = {
            'BraTS21ID': list(map(lambda x: x.item(), patient_ids_all)), 
            'probability': probabilities_all,
            'label': labels_all
        }
        result = pd.DataFrame(result)
        slice_auc = roc_auc_score(result['label'], result['probability'])
        result = result.groupby("BraTS21ID", as_index=False).mean()
        patient_auc = roc_auc_score(result['label'], result['probability'])
        print('Patient AUC: {:.5f} - Slice AUC: {:.5f}'.format(patient_auc, slice_auc))
        
        return summary_loss.avg, patient_auc, result
    
    def infer_epoch(self, loader, verbose):
        self.model.eval()
        start = time.time()
        n = len(loader)
        patient_ids_all = []
        probabilities_all = []
        with torch.no_grad():
            for step, batch_data in enumerate(loader):
                inputs, patient_ids = (
                    batch_data["image"].to(self.device), # (None, 1, 32, 32)
                    batch_data["patient_id"], # (None, )
                )
                batch_size = inputs.size(0)
                # forward
                outputs = self.model(inputs) # (None, 2)
                # update stats
                probabilities = F.softmax(outputs, dim=1)[:, 1].tolist()
                probabilities_all.extend(probabilities)
                patient_ids_all.extend(patient_ids)
                if verbose:
                    print('Infer step {}/{}'.format(step + 1, n), end='\r')
        
        result = {
            'BraTS21ID': list(map(lambda x: x.item(), patient_ids_all)), 
            'probability': probabilities_all,
        }
        result = pd.DataFrame(result)
        result = result.groupby("BraTS21ID", as_index=False).mean()
        
        elapsed_time = str(datetime.timedelta(seconds=time.time() - start))
        print('Elapsed time: {}'.format(elapsed_time))
        
        return result
    
    def fit(self, train_ds, val_ds, val_holdout_ds, batch_size, epochs, lr, model_name, verbose):
        train_loader = DataLoader(train_ds, 
                                  batch_size=batch_size, 
                                  shuffle=True,
                                  num_workers=self.args.n_workers)
        val_loader = DataLoader(val_ds, 
                                batch_size=batch_size, 
                                shuffle=False,
                                num_workers=self.args.n_workers)
        val_holdout_loader = DataLoader(val_holdout_ds, 
                                        batch_size=batch_size, 
                                        shuffle=False,
                                        num_workers=self.args.n_workers)
        loss_function = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)
        
        current_metric = -np.inf
        current_loss = np.inf
        current_epoch = 1
        current_state_dict = None
        save_path = '{}_imgsize{}_valloss{:.3f}_valauc{:.3f}.pth'
        for epoch in range(1, epochs + 1):
            print('\nEpoch {}/{}:'.format(epoch, epochs))
            train_loss = self.train_epoch(train_loader, loss_function, optimizer, verbose)
            print(' Validation:')
            val_loss, val_metric, _ = self.evaluate_epoch(val_loader, loss_function, verbose)
            print(' Hold out:')
            val_holdout_loss, val_holdout_metric, _ = self.evaluate_epoch(val_holdout_loader, 
                                                                          loss_function, 
                                                                          verbose)
            
#             if val_loss < current_loss:
            if val_metric > current_metric:
                print('Val AUC improved from {:.5f} to {:.5f}'.format(current_metric, val_metric))
                current_metric = val_metric
                current_loss = val_loss
                current_epoch = epoch
                current_state_dict = deepcopy(self.model.state_dict())
                
            elif (epoch - current_epoch) > self.args.early_stopping_rounds:
                print('Early stopping. Best model is epoch {}'.format(current_epoch))
                print('Val loss: {:.5f}, Val auc: {:.5f}'.format(current_loss, current_metric))
                print('Saving model...')
                torch.save(current_state_dict, 
                           save_path.format(model_name,
                                            self.args.img_size, 
                                            current_loss, 
                                            current_metric))
                break
            if epoch == epochs:
                print('Finished training. Best model is epoch {}'.format(current_epoch))
                print('Val loss: {:.5f}, Val auc: {:.5f}'.format(current_loss, current_metric))
                print('Saving model...')
                torch.save(current_state_dict, 
                           save_path.format(model_name,
                                            self.args.img_size, 
                                            current_loss, 
                                            current_metric))
                
    def evaluate(self, val_holdout_ds, batch_size, verbose):
        val_holdout_loader = DataLoader(val_holdout_ds, 
                                        batch_size=batch_size, 
                                        shuffle=False,
                                        num_workers=self.args.n_workers)
        loss_function = nn.CrossEntropyLoss()
        print(' Hold out:')
        _, val_holdout_metric, val_holdout_result = self.evaluate_epoch(val_holdout_loader, 
                                                                        loss_function, 
                                                                        verbose)
        return val_holdout_metric, val_holdout_result
    
    def predict(self, test_ds, batch_size, verbose):
        test_loader = DataLoader(test_ds, 
                                 batch_size=batch_size, 
                                 shuffle=False,
                                 num_workers=self.args.n_workers)
        test_result = self.infer_epoch(test_loader, verbose)
        return test_result

# %%
mri_types = ['T1wCE']
img_size = 32
batch_size = 32
n_workers = 4
early_stopping_rounds = 3
n_folds = 5
epochs = 50
lr = 1e-3

# %%
args = Config(img_size=img_size, 
              n_workers=n_workers, 
              early_stopping_rounds=early_stopping_rounds,
              n_folds=n_folds)
pipeline = Pipeline(args)

# %% [markdown]
# ## Train

# %%
pipeline.load_annotations()
for fold in range(n_folds):
    print(f'### Train {mri_types} on fold {fold}: ###')
    train_ds, val_ds, val_holdout_ds = pipeline.prepare_datasets(mri_types=mri_types, 
                                                                 fold=fold,
                                                                 cache_rate=1.0)
    pipeline.load_model()
    pipeline.fit(train_ds, val_ds, val_holdout_ds,
                 batch_size=batch_size, epochs=epochs, lr=lr, 
                 model_name=f'{"_".join(mri_types)}_fold{fold}',
                 verbose=True)
# Out:
# ### Train ['T1wCE'] on fold 0: ###
# 100%|██████████| 465/465 [00:08<00:00, 51.78it/s]
# Loading dataset: 100%|██████████| 10317/10317 [00:34<00:00, 299.08it/s]
# 100%|██████████| 465/465 [00:00<00:00, 538.11it/s]
# Loading dataset: 100%|██████████| 2580/2580 [00:08<00:00, 297.88it/s]
# 100%|██████████| 117/117 [00:02<00:00, 48.44it/s]
# Loading dataset: 100%|██████████| 3299/3299 [00:11<00:00, 299.81it/s]
# Epoch 1/50:
# Train loss: 0.68535 - time: 0:00:03.711379
#  Validation:
# Val loss: 0.67889 - time: 0:00:00.639530
# Patient AUC: 0.58403 - Slice AUC: 0.59365
#  Hold out:
# Val loss: 0.68701 - time: 0:00:00.768204
# Patient AUC: 0.60235 - Slice AUC: 0.56842
# Val AUC improved from -inf to 0.58403
#
# Epoch 2/50:
# Train loss: 0.68121 - time: 0:00:03.581786
#  Validation:
# Val loss: 0.67336 - time: 0:00:00.644600
# Patient AUC: 0.59802 - Slice AUC: 0.60609
#  Hold out:
# Val loss: 0.68926 - time: 0:00:01.182018
# Patient AUC: 0.60176 - Slice AUC: 0.57000
# Val AUC improved from 0.58403 to 0.59802
#
# Epoch 3/50:
# Train loss: 0.67890 - time: 0:00:04.054740
#  Validation:
# Val loss: 0.67148 - time: 0:00:00.931953
# Patient AUC: 0.60027 - Slice AUC: 0.60966
#  Hold out:
# Val loss: 0.68384 - time: 0:00:00.785311
# Patient AUC: 0.60587 - Slice AUC: 0.57171
# Val AUC improved from 0.59802 to 0.60027
#
# Epoch 4/50:
# Train loss: 0.67315 - time: 0:00:03.715514
#  Validation:
# Val loss: 0.66991 - time: 0:00:00.735603
# Patient AUC: 0.61896 - Slice AUC: 0.62101
#  Hold out:
# Val loss: 0.69086 - time: 0:00:00.930682
# Patient AUC: 0.57361 - Slice AUC: 0.55510
# Val AUC improved from 0.60027 to 0.61896
#
# Epoch 5/50:
# Train loss: 0.66466 - time: 0:00:03.876081
#  Validation:
# Val loss: 0.66832 - time: 0:00:00.677217
# Patient AUC: 0.62384 - Slice AUC: 0.62763
#  Hold out:
# Val loss: 0.71263 - time: 0:00:00.835419
# Patient AUC: 0.59501 - Slice AUC: 0.55397
# Val AUC improved from 0.61896 to 0.62384
#
# Epoch 6/50:
# Train loss: 0.65806 - time: 0:00:03.736665
#  Validation:
# Val loss: 0.65870 - time: 0:00:00.638645
# Patient AUC: 0.65807 - Slice AUC: 0.63586
#  Hold out:
# Val loss: 0.70938 - time: 0:00:00.964021
# Patient AUC: 0.58240 - Slice AUC: 0.53775
# Val AUC improved from 0.62384 to 0.65807
#
# Epoch 7/50:
# Train loss: 0.64902 - time: 0:00:03.578694
#  Validation:
# Val loss: 0.65211 - time: 0:00:00.643919
# Patient AUC: 0.65214 - Slice AUC: 0.65090
#  Hold out:
# Val loss: 0.72247 - time: 0:00:00.775504
# Patient AUC: 0.59853 - Slice AUC: 0.55975
#
# Epoch 8/50:
# Train loss: 0.64313 - time: 0:00:03.969939
#  Validation:
# Val loss: 0.64365 - time: 0:00:00.694792
# Patient AUC: 0.67795 - Slice AUC: 0.66318
#  Hold out:
# Val loss: 0.72781 - time: 0:00:01.074070
# Patient AUC: 0.59472 - Slice AUC: 0.55053
# Val AUC improved from 0.65807 to 0.67795
#
# Epoch 9/50:
# Train loss: 0.63157 - time: 0:00:03.997982
#  Validation:
# Val loss: 0.64429 - time: 0:00:00.656809
# Patient AUC: 0.70395 - Slice AUC: 0.66711
#  Hold out:
# Val loss: 0.70811 - time: 0:00:00.830193
# Patient AUC: 0.59326 - Slice AUC: 0.54722
# Val AUC improved from 0.67795 to 0.70395
#
# Epoch 10/50:
# Train loss: 0.62267 - time: 0:00:03.786697
#  Validation:
# Val loss: 0.64998 - time: 0:00:00.701008
# Patient AUC: 0.68560 - Slice AUC: 0.66244
#  Hold out:
# Val loss: 0.77583 - time: 0:00:01.067197
# Patient AUC: 0.56804 - Slice AUC: 0.53791
#
# Epoch 11/50:
# Train loss: 0.61556 - time: 0:00:03.744196
#  Validation:
# Val loss: 0.62788 - time: 0:00:00.662355
# Patient AUC: 0.72936 - Slice AUC: 0.69074
#  Hold out:
# Val loss: 0.76585 - time: 0:00:00.887668
# Patient AUC: 0.56012 - Slice AUC: 0.52678
# Val AUC improved from 0.70395 to 0.72936
#
# Epoch 12/50:
# Train loss: 0.60464 - time: 0:00:03.614405
#  Validation:
# Val loss: 0.61544 - time: 0:00:00.671984
# Patient AUC: 0.75520 - Slice AUC: 0.70481
#  Hold out:
# Val loss: 0.78375 - time: 0:00:01.022589
# Patient AUC: 0.57713 - Slice AUC: 0.53541
# Val AUC improved from 0.72936 to 0.75520
#
# Epoch 13/50:
# Train loss: 0.59694 - time: 0:00:03.764024
#  Validation:
# Val loss: 0.61610 - time: 0:00:00.703592
# Patient AUC: 0.76396 - Slice AUC: 0.70469
#  Hold out:
# Val loss: 0.79770 - time: 0:00:00.819985
# Patient AUC: 0.54076 - Slice AUC: 0.51677
# Val AUC improved from 0.75520 to 0.76396
#
# Epoch 14/50:
# Train loss: 0.58463 - time: 0:00:03.624109
#  Validation:
# Val loss: 0.60792 - time: 0:00:00.655105
# Patient AUC: 0.78515 - Slice AUC: 0.71830
#  Hold out:
# Val loss: 0.80549 - time: 0:00:00.803159
# Patient AUC: 0.55015 - Slice AUC: 0.52438
# Val AUC improved from 0.76396 to 0.78515
#
# Epoch 15/50:
# Train loss: 0.57473 - time: 0:00:04.077343
#  Validation:
# Val loss: 0.60177 - time: 0:00:00.776336
# Patient AUC: 0.80562 - Slice AUC: 0.72603
#  Hold out:
# Val loss: 0.81569 - time: 0:00:00.797298
# Patient AUC: 0.54164 - Slice AUC: 0.51738
# Val AUC improved from 0.78515 to 0.80562
#
# Epoch 16/50:
# Train loss: 0.56722 - time: 0:00:03.645410
#  Validation:
# Val loss: 0.59477 - time: 0:00:00.808145
# Patient AUC: 0.80331 - Slice AUC: 0.73247
#  Hold out:
# Val loss: 0.84872 - time: 0:00:00.879103
# Patient AUC: 0.51906 - Slice AUC: 0.50119
#
# Epoch 17/50:
# Train loss: 0.55222 - time: 0:00:03.900978
#  Validation:
# Val loss: 0.59220 - time: 0:00:00.647605
# Patient AUC: 0.81405 - Slice AUC: 0.74680
#  Hold out:
# Val loss: 0.91648 - time: 0:00:00.797179
# Patient AUC: 0.52082 - Slice AUC: 0.50159
# Val AUC improved from 0.80562 to 0.81405
#
# Epoch 18/50:
# Train loss: 0.54599 - time: 0:00:03.621916
#  Validation:
# Val loss: 0.60100 - time: 0:00:00.645041
# Patient AUC: 0.80669 - Slice AUC: 0.73624
#  Hold out:
# Val loss: 0.96499 - time: 0:00:00.785018
# Patient AUC: 0.47771 - Slice AUC: 0.47781
#
# Epoch 19/50:
# Train loss: 0.53729 - time: 0:00:03.973342
#  Validation:
# Val loss: 0.58461 - time: 0:00:00.655097
# Patient AUC: 0.82553 - Slice AUC: 0.74979
#  Hold out:
# Val loss: 0.95844 - time: 0:00:00.788272
# Patient AUC: 0.48563 - Slice AUC: 0.48430
# Val AUC improved from 0.81405 to 0.82553
#
# Epoch 20/50:
# Train loss: 0.52709 - time: 0:00:03.606194
#  Validation:
# Val loss: 0.57211 - time: 0:00:00.652468
# Patient AUC: 0.86284 - Slice AUC: 0.76817
#  Hold out:
# Val loss: 0.94276 - time: 0:00:00.780804
# Patient AUC: 0.50323 - Slice AUC: 0.49316
# Val AUC improved from 0.82553 to 0.86284
#
# Epoch 21/50:
# Train loss: 0.51721 - time: 0:00:03.988496
#  Validation:
# Val loss: 0.57902 - time: 0:00:00.646389
# Patient AUC: 0.83840 - Slice AUC: 0.76060
#  Hold out:
# Val loss: 1.00498 - time: 0:00:01.204007
# Patient AUC: 0.47097 - Slice AUC: 0.47511
#
# Epoch 22/50:
# Train loss: 0.50736 - time: 0:00:03.811296
#  Validation:
# Val loss: 0.56688 - time: 0:00:00.651769
# Patient AUC: 0.86707 - Slice AUC: 0.77164
#  Hold out:
# Val loss: 1.01810 - time: 0:00:00.806720
# Patient AUC: 0.47625 - Slice AUC: 0.48762
# Val AUC improved from 0.86284 to 0.86707
#
# Epoch 23/50:
# Train loss: 0.50463 - time: 0:00:04.002199
#  Validation:
# Val loss: 0.57334 - time: 0:00:00.669030
# Patient AUC: 0.86999 - Slice AUC: 0.77179
#  Hold out:
# Val loss: 0.96588 - time: 0:00:00.825707
# Patient AUC: 0.49443 - Slice AUC: 0.48903
# Val AUC improved from 0.86707 to 0.86999
#
# Epoch 24/50:
# Train loss: 0.49085 - time: 0:00:03.745081
#  Validation:
# Val loss: 0.55626 - time: 0:00:00.695851
# Patient AUC: 0.86798 - Slice AUC: 0.77990
#  Hold out:
# Val loss: 1.03065 - time: 0:00:00.975746
# Patient AUC: 0.46686 - Slice AUC: 0.47693
#
# Epoch 25/50:
# Train loss: 0.48640 - time: 0:00:03.803695
#  Validation:
# Val loss: 0.55840 - time: 0:00:00.649292
# Patient AUC: 0.86868 - Slice AUC: 0.78217
#  Hold out:
# Val loss: 1.07005 - time: 0:00:00.813541
# Patient AUC: 0.48123 - Slice AUC: 0.47954
#
# Epoch 26/50:
# Train loss: 0.46929 - time: 0:00:03.623166
#  Validation:
# Val loss: 0.56410 - time: 0:00:00.647819
# Patient AUC: 0.87622 - Slice AUC: 0.78179
#  Hold out:
# Val loss: 1.12087 - time: 0:00:00.824172
# Patient AUC: 0.46422 - Slice AUC: 0.47506
# Val AUC improved from 0.86999 to 0.87622
#
# Epoch 27/50:
# Train loss: 0.46778 - time: 0:00:03.785170
#  Validation:
# Val loss: 0.55306 - time: 0:00:00.680925
# Patient AUC: 0.88969 - Slice AUC: 0.79328
#  Hold out:
# Val loss: 1.06843 - time: 0:00:01.000926
# Patient AUC: 0.45865 - Slice AUC: 0.47661
# Val AUC improved from 0.87622 to 0.88969
#
# Epoch 28/50:
# Train loss: 0.45756 - time: 0:00:03.998603
#  Validation:
# Val loss: 0.55099 - time: 0:00:00.660985
# Patient AUC: 0.88507 - Slice AUC: 0.79038
#  Hold out:
# Val loss: 1.11961 - time: 0:00:00.784197
# Patient AUC: 0.44047 - Slice AUC: 0.46086
#
# Epoch 29/50:
# Train loss: 0.45596 - time: 0:00:03.777611
#  Validation:
# Val loss: 0.54408 - time: 0:00:00.642590
# Patient AUC: 0.89560 - Slice AUC: 0.79771
#  Hold out:
# Val loss: 1.08139 - time: 0:00:00.780833
# Patient AUC: 0.46657 - Slice AUC: 0.47676
# Val AUC improved from 0.88969 to 0.89560
#
# Epoch 30/50:
# Train loss: 0.44810 - time: 0:00:03.749464
#  Validation:
# Val loss: 0.54462 - time: 0:00:00.642421
# Patient AUC: 0.89870 - Slice AUC: 0.79907
#  Hold out:
# Val loss: 1.08939 - time: 0:00:00.788576
# Patient AUC: 0.44545 - Slice AUC: 0.46751
# Val AUC improved from 0.89560 to 0.89870
#
# Epoch 31/50:
# Train loss: 0.43895 - time: 0:00:03.770133
#  Validation:
# Val loss: 0.55004 - time: 0:00:00.642326
# Patient AUC: 0.87887 - Slice AUC: 0.80236
#  Hold out:
# Val loss: 1.22259 - time: 0:00:00.780009
# Patient AUC: 0.46745 - Slice AUC: 0.47405
#
# Epoch 32/50:
# Train loss: 0.42655 - time: 0:00:03.821086
#  Validation:
# Val loss: 0.53661 - time: 0:00:00.671234
# Patient AUC: 0.90349 - Slice AUC: 0.80879
#  Hold out:
# Val loss: 1.13902 - time: 0:00:00.815811
# Patient AUC: 0.48856 - Slice AUC: 0.48354
# Val AUC improved from 0.89870 to 0.90349
#
# Epoch 33/50:
# Train loss: 0.41964 - time: 0:00:03.836717
#  Validation:
# Val loss: 0.53717 - time: 0:00:00.664809
# Patient AUC: 0.89760 - Slice AUC: 0.81274
#  Hold out:
# Val loss: 1.15061 - time: 0:00:00.819536
# Patient AUC: 0.46012 - Slice AUC: 0.47181
#
# Epoch 34/50:
# Train loss: 0.40516 - time: 0:00:04.538997
#  Validation:
# Val loss: 0.54396 - time: 0:00:00.640082
# Patient AUC: 0.90434 - Slice AUC: 0.81454
#  Hold out:
# Val loss: 1.28475 - time: 0:00:00.784184
# Patient AUC: 0.45572 - Slice AUC: 0.46346
# Val AUC improved from 0.90349 to 0.90434
#
# Epoch 35/50:
# Train loss: 0.40321 - time: 0:00:03.773787
#  Validation:
# Val loss: 0.56362 - time: 0:00:00.650864
# Patient AUC: 0.89581 - Slice AUC: 0.80819
#  Hold out:
# Val loss: 1.28556 - time: 0:00:00.787675
# Patient AUC: 0.47977 - Slice AUC: 0.46946
#
# Epoch 36/50:
# Train loss: 0.40218 - time: 0:00:03.746134
#  Validation:
# Val loss: 0.55043 - time: 0:00:00.647653
# Patient AUC: 0.89849 - Slice AUC: 0.81557
#  Hold out:
# Val loss: 1.31753 - time: 0:00:00.768732
# Patient AUC: 0.45367 - Slice AUC: 0.46546
#
# Epoch 37/50:
# Train loss: 0.38658 - time: 0:00:03.763893
#  Validation:
# Val loss: 0.54255 - time: 0:00:00.641331
# Patient AUC: 0.89281 - Slice AUC: 0.81885
#  Hold out:
# Val loss: 1.31720 - time: 0:00:00.781711
# Patient AUC: 0.45894 - Slice AUC: 0.46130
#
# Epoch 38/50:
# Train loss: 0.38386 - time: 0:00:03.728855
#  Validation:
# Val loss: 0.53569 - time: 0:00:00.648662
# Patient AUC: 0.90979 - Slice AUC: 0.82104
#  Hold out:
# Val loss: 1.29825 - time: 0:00:00.778239
# Patient AUC: 0.44868 - Slice AUC: 0.45471
# Val AUC improved from 0.90434 to 0.90979
#
# Epoch 39/50:
# Train loss: 0.37003 - time: 0:00:03.766822
#  Validation:
# Val loss: 0.53533 - time: 0:00:00.637517
# Patient AUC: 0.90934 - Slice AUC: 0.82456
#  Hold out:
# Val loss: 1.38668 - time: 0:00:01.069459
# Patient AUC: 0.43754 - Slice AUC: 0.45015
#
# Epoch 40/50:
# Train loss: 0.36971 - time: 0:00:04.160369
#  Validation:
# Val loss: 0.53311 - time: 0:00:00.637496
# Patient AUC: 0.91237 - Slice AUC: 0.82249
#  Hold out:
# Val loss: 1.28429 - time: 0:00:00.773045
# Patient AUC: 0.42874 - Slice AUC: 0.45605
# Val AUC improved from 0.90979 to 0.91237
#
# Epoch 41/50:
# Train loss: 0.36141 - time: 0:00:03.771337
#  Validation:
# Val loss: 0.52947 - time: 0:00:00.695814
# Patient AUC: 0.90514 - Slice AUC: 0.83202
#  Hold out:
# Val loss: 1.33759 - time: 0:00:00.783416
# Patient AUC: 0.41232 - Slice AUC: 0.44525
#
# Epoch 42/50:
# Train loss: 0.35392 - time: 0:00:03.576468
#  Validation:
# Val loss: 0.52930 - time: 0:00:00.641833
# Patient AUC: 0.89969 - Slice AUC: 0.83072
#  Hold out:
# Val loss: 1.36824 - time: 0:00:00.773155
# Patient AUC: 0.46246 - Slice AUC: 0.46610
#
# Epoch 43/50:
# Train loss: 0.34290 - time: 0:00:03.732095
#  Validation:
# Val loss: 0.53316 - time: 0:00:00.801075
# Patient AUC: 0.91539 - Slice AUC: 0.83347
#  Hold out:
# Val loss: 1.46764 - time: 0:00:00.773373
# Patient AUC: 0.41026 - Slice AUC: 0.44033
# Val AUC improved from 0.91237 to 0.91539
#
# Epoch 44/50:
# Train loss: 0.34097 - time: 0:00:03.682109
#  Validation:
# Val loss: 0.52893 - time: 0:00:00.668543
# Patient AUC: 0.91306 - Slice AUC: 0.83566
#  Hold out:
# Val loss: 1.36375 - time: 0:00:00.774191
# Patient AUC: 0.41877 - Slice AUC: 0.44941
#
# Epoch 45/50:
# Train loss: 0.32847 - time: 0:00:03.739182
#  Validation:
# Val loss: 0.53928 - time: 0:00:00.886215
# Patient AUC: 0.91388 - Slice AUC: 0.83716
#  Hold out:
# Val loss: 1.55113 - time: 0:00:01.191770
# Patient AUC: 0.39736 - Slice AUC: 0.42998
#
# Epoch 46/50:
# Train loss: 0.32693 - time: 0:00:04.095789
#  Validation:
# Val loss: 0.52077 - time: 0:00:00.644040
# Patient AUC: 0.91332 - Slice AUC: 0.84421
#  Hold out:
# Val loss: 1.50959 - time: 0:00:00.761641
# Patient AUC: 0.45924 - Slice AUC: 0.45601
#
# Epoch 47/50:
# Train loss: 0.31725 - time: 0:00:03.850418
#  Validation:
# Val loss: 0.52833 - time: 0:00:00.754487
# Patient AUC: 0.91318 - Slice AUC: 0.84191
#  Hold out:
# Val loss: 1.55415 - time: 0:00:00.793435
# Patient AUC: 0.43226 - Slice AUC: 0.44673
# Early stopping. Best model is epoch 43
# Val loss: 0.53316, Val auc: 0.91539
# Saving model...
# ### Train ['T1wCE'] on fold 1: ###
# 100%|██████████| 465/465 [00:00<00:00, 482.72it/s]
# Loading dataset: 100%|██████████| 10437/10437 [00:31<00:00, 336.24it/s]
# 100%|██████████| 465/465 [00:00<00:00, 583.66it/s]
# Loading dataset: 100%|██████████| 2610/2610 [00:07<00:00, 349.55it/s]
# 100%|██████████| 117/117 [00:00<00:00, 453.08it/s]
# Loading dataset: 100%|██████████| 3149/3149 [00:09<00:00, 346.27it/s]
# Epoch 1/50:
# Train loss: 0.67898 - time: 0:00:04.320052
#  Validation:
# Val loss: 0.68940 - time: 0:00:00.657396
# Patient AUC: 0.61370 - Slice AUC: 0.58954
#  Hold out:
# Val loss: 0.69982 - time: 0:00:00.809674
# Patient AUC: 0.52635 - Slice AUC: 0.52039
# Val AUC improved from -inf to 0.61370
#
# Epoch 2/50:
# Train loss: 0.67141 - time: 0:00:04.111772
#  Validation:
# Val loss: 0.67260 - time: 0:00:00.716331
# Patient AUC: 0.62930 - Slice AUC: 0.61079
#  Hold out:
# Val loss: 0.70947 - time: 0:00:00.805286
# Patient AUC: 0.52283 - Slice AUC: 0.51242
# Val AUC improved from 0.61370 to 0.62930
#
# Epoch 3/50:
# Train loss: 0.66017 - time: 0:00:03.904916
#  Validation:
# Val loss: 0.67450 - time: 0:00:00.706395
# Patient AUC: 0.65397 - Slice AUC: 0.62409
#  Hold out:
# Val loss: 0.72969 - time: 0:00:00.857139
# Patient AUC: 0.54947 - Slice AUC: 0.53265
# Val AUC improved from 0.62930 to 0.65397
#
# Epoch 4/50:
# Train loss: 0.65311 - time: 0:00:03.717113
#  Validation:
# Val loss: 0.65404 - time: 0:00:00.672204
# Patient AUC: 0.67276 - Slice AUC: 0.65383
#  Hold out:
# Val loss: 0.73424 - time: 0:00:00.782718
# Patient AUC: 0.52722 - Slice AUC: 0.50524
# Val AUC improved from 0.65397 to 0.67276
#
# Epoch 5/50:
# Train loss: 0.63272 - time: 0:00:03.846516
#  Validation:
# Val loss: 0.63438 - time: 0:00:00.828033
# Patient AUC: 0.70032 - Slice AUC: 0.68358
#  Hold out:
# Val loss: 0.73161 - time: 0:00:00.787084
# Patient AUC: 0.51493 - Slice AUC: 0.51799
# Val AUC improved from 0.67276 to 0.70032
#
# Epoch 6/50:
# Train loss: 0.60875 - time: 0:00:03.675120
#  Validation:
# Val loss: 0.62870 - time: 0:00:00.665974
# Patient AUC: 0.73000 - Slice AUC: 0.70114
#  Hold out:
# Val loss: 0.79919 - time: 0:00:00.777611
# Patient AUC: 0.52459 - Slice AUC: 0.49975
# Val AUC improved from 0.70032 to 0.73000
#
# Epoch 7/50:
# Train loss: 0.58179 - time: 0:00:04.489194
#  Validation:
# Val loss: 0.59459 - time: 0:00:00.691787
# Patient AUC: 0.78898 - Slice AUC: 0.73448
#  Hold out:
# Val loss: 0.84153 - time: 0:00:00.823186
# Patient AUC: 0.52459 - Slice AUC: 0.50122
# Val AUC improved from 0.73000 to 0.78898
#
# Epoch 8/50:
# Train loss: 0.55301 - time: 0:00:03.980007
#  Validation:
# Val loss: 0.58433 - time: 0:00:00.670126
# Patient AUC: 0.80653 - Slice AUC: 0.75266
#  Hold out:
# Val loss: 0.83898 - time: 0:00:00.778199
# Patient AUC: 0.56118 - Slice AUC: 0.52161
# Val AUC improved from 0.78898 to 0.80653
#
# Epoch 9/50:
# Train loss: 0.52301 - time: 0:00:03.975294
#  Validation:
# Val loss: 0.57097 - time: 0:00:00.670967
# Patient AUC: 0.82355 - Slice AUC: 0.77163
#  Hold out:
# Val loss: 0.96174 - time: 0:00:00.805212
# Patient AUC: 0.52020 - Slice AUC: 0.50046
# Val AUC improved from 0.80653 to 0.82355
#
# Epoch 10/50:
# Train loss: 0.49350 - time: 0:00:03.707795
#  Validation:
# Val loss: 0.55198 - time: 0:00:00.675018
# Patient AUC: 0.84255 - Slice AUC: 0.78478
#  Hold out:
# Val loss: 0.94042 - time: 0:00:00.764424
# Patient AUC: 0.54977 - Slice AUC: 0.52720
# Val AUC improved from 0.82355 to 0.84255
#
# Epoch 11/50:
# Train loss: 0.46103 - time: 0:00:04.022378
#  Validation:
# Val loss: 0.54287 - time: 0:00:00.696458
# Patient AUC: 0.86394 - Slice AUC: 0.80103
#  Hold out:
# Val loss: 1.02929 - time: 0:00:00.815069
# Patient AUC: 0.51786 - Slice AUC: 0.50589
# Val AUC improved from 0.84255 to 0.86394
#
# Epoch 12/50:
# Train loss: 0.44224 - time: 0:00:03.746145
#  Validation:
# Val loss: 0.53695 - time: 0:00:00.675718
# Patient AUC: 0.86578 - Slice AUC: 0.80580
#  Hold out:
# Val loss: 1.05172 - time: 0:00:00.777605
# Patient AUC: 0.53308 - Slice AUC: 0.51057
# Val AUC improved from 0.86394 to 0.86578
#
# Epoch 13/50:
# Train loss: 0.41099 - time: 0:00:04.210594
#  Validation:
# Val loss: 0.53289 - time: 0:00:00.670555
# Patient AUC: 0.87795 - Slice AUC: 0.81693
#  Hold out:
# Val loss: 1.14006 - time: 0:00:00.832402
# Patient AUC: 0.53425 - Slice AUC: 0.52034
# Val AUC improved from 0.86578 to 0.87795
#
# Epoch 14/50:
# Train loss: 0.39236 - time: 0:00:04.063143
#  Validation:
# Val loss: 0.52403 - time: 0:00:00.681602
# Patient AUC: 0.87678 - Slice AUC: 0.81682
#  Hold out:
# Val loss: 1.06061 - time: 0:00:00.805326
# Patient AUC: 0.55357 - Slice AUC: 0.52804
#
# Epoch 15/50:
# Train loss: 0.36743 - time: 0:00:03.843302
#  Validation:
# Val loss: 0.51409 - time: 0:00:00.660225
# Patient AUC: 0.89472 - Slice AUC: 0.83101
#  Hold out:
# Val loss: 1.17541 - time: 0:00:00.775794
# Patient AUC: 0.53513 - Slice AUC: 0.52564
# Val AUC improved from 0.87795 to 0.89472
#
# Epoch 16/50:
# Train loss: 0.34864 - time: 0:00:03.718226
#  Validation:
# Val loss: 0.51516 - time: 0:00:00.663933
# Patient AUC: 0.88812 - Slice AUC: 0.83700
#  Hold out:
# Val loss: 1.22253 - time: 0:00:00.801496
# Patient AUC: 0.51961 - Slice AUC: 0.51166
#
# Epoch 17/50:
# Train loss: 0.32777 - time: 0:00:03.741506
#  Validation:
# Val loss: 0.50745 - time: 0:00:00.757652
# Patient AUC: 0.90167 - Slice AUC: 0.84536
#  Hold out:
# Val loss: 1.26660 - time: 0:00:00.766955
# Patient AUC: 0.52430 - Slice AUC: 0.51076
# Val AUC improved from 0.89472 to 0.90167
#
# Epoch 18/50:
# Train loss: 0.30865 - time: 0:00:03.664001
#  Validation:
# Val loss: 0.53103 - time: 0:00:00.668998
# Patient AUC: 0.89279 - Slice AUC: 0.84120
#  Hold out:
# Val loss: 1.41089 - time: 0:00:00.824244
# Patient AUC: 0.54450 - Slice AUC: 0.52022
#
# Epoch 19/50:
# Train loss: 0.28940 - time: 0:00:04.733876
#  Validation:
# Val loss: 0.52119 - time: 0:00:00.933537
# Patient AUC: 0.90068 - Slice AUC: 0.84846
#  Hold out:
# Val loss: 1.44774 - time: 0:00:00.796507
# Patient AUC: 0.53835 - Slice AUC: 0.52397
#
# Epoch 20/50:
# Train loss: 0.27048 - time: 0:00:04.023503
#  Validation:
# Val loss: 0.50720 - time: 0:00:00.672114
# Patient AUC: 0.91372 - Slice AUC: 0.86025
#  Hold out:
# Val loss: 1.53332 - time: 0:00:00.792868
# Patient AUC: 0.53044 - Slice AUC: 0.51186
# Val AUC improved from 0.90167 to 0.91372
#
# Epoch 21/50:
# Train loss: 0.25582 - time: 0:00:03.813897
#  Validation:
# Val loss: 0.53446 - time: 0:00:00.666782
# Patient AUC: 0.90977 - Slice AUC: 0.85981
#  Hold out:
# Val loss: 1.60899 - time: 0:00:00.780795
# Patient AUC: 0.52957 - Slice AUC: 0.51590
#
# Epoch 22/50:
# Train loss: 0.24647 - time: 0:00:03.686057
#  Validation:
# Val loss: 0.51492 - time: 0:00:00.673353
# Patient AUC: 0.92087 - Slice AUC: 0.86374
#  Hold out:
# Val loss: 1.55515 - time: 0:00:00.770699
# Patient AUC: 0.51874 - Slice AUC: 0.50661
# Val AUC improved from 0.91372 to 0.92087
#
# Epoch 23/50:
# Train loss: 0.24515 - time: 0:00:03.751719
#  Validation:
# Val loss: 0.52513 - time: 0:00:00.728634
# Patient AUC: 0.91688 - Slice AUC: 0.86643
#  Hold out:
# Val loss: 1.64889 - time: 0:00:00.755843
# Patient AUC: 0.52869 - Slice AUC: 0.50771
#
# Epoch 24/50:
# Train loss: 0.21856 - time: 0:00:03.659231
#  Validation:
# Val loss: 0.54475 - time: 0:00:00.788618
# Patient AUC: 0.91809 - Slice AUC: 0.86110
#  Hold out:
# Val loss: 1.67960 - time: 0:00:01.124862
# Patient AUC: 0.55006 - Slice AUC: 0.51943
#
# Epoch 25/50:
# Train loss: 0.21312 - time: 0:00:03.862586
#  Validation:
# Val loss: 0.54537 - time: 0:00:00.773216
# Patient AUC: 0.91609 - Slice AUC: 0.86969
#  Hold out:
# Val loss: 1.74481 - time: 0:00:00.766178
# Patient AUC: 0.52752 - Slice AUC: 0.51825
#
# Epoch 26/50:
# Train loss: 0.20403 - time: 0:00:04.062467
#  Validation:
# Val loss: 0.56089 - time: 0:00:00.677285
# Patient AUC: 0.91941 - Slice AUC: 0.87392
#  Hold out:
# Val loss: 1.91555 - time: 0:00:00.857120
# Patient AUC: 0.54333 - Slice AUC: 0.51648
# Early stopping. Best model is epoch 22
# Val loss: 0.51492, Val auc: 0.92087
# Saving model...
# ### Train ['T1wCE'] on fold 2: ###
# 100%|██████████| 466/466 [00:00<00:00, 475.35it/s]
# Loading dataset: 100%|██████████| 10248/10248 [00:29<00:00, 342.13it/s]
# 100%|██████████| 466/466 [00:00<00:00, 583.74it/s]
# Loading dataset: 100%|██████████| 2562/2562 [00:07<00:00, 335.36it/s]
# 100%|██████████| 116/116 [00:00<00:00, 459.37it/s]
# Loading dataset: 100%|██████████| 3386/3386 [00:09<00:00, 348.99it/s]
# Epoch 1/50:
# Train loss: 0.68612 - time: 0:00:04.289785
#  Validation:
# Val loss: 0.68509 - time: 0:00:00.993450
# Patient AUC: 0.55936 - Slice AUC: 0.57183
#  Hold out:
# Val loss: 0.67084 - time: 0:00:00.879693
# Patient AUC: 0.58838 - Slice AUC: 0.59110
# Val AUC improved from -inf to 0.55936
#
# Epoch 2/50:
# Train loss: 0.68087 - time: 0:00:03.811641
#  Validation:
# Val loss: 0.67837 - time: 0:00:00.661708
# Patient AUC: 0.59370 - Slice AUC: 0.59042
#  Hold out:
# Val loss: 0.68100 - time: 0:00:00.877582
# Patient AUC: 0.56215 - Slice AUC: 0.56687
# Val AUC improved from 0.55936 to 0.59370
#
# Epoch 3/50:
# Train loss: 0.67523 - time: 0:00:03.958835
#  Validation:
# Val loss: 0.67550 - time: 0:00:00.670949
# Patient AUC: 0.61087 - Slice AUC: 0.60430
#  Hold out:
# Val loss: 0.68508 - time: 0:00:00.870734
# Patient AUC: 0.55440 - Slice AUC: 0.55646
# Val AUC improved from 0.59370 to 0.61087
#
# Epoch 4/50:
# Train loss: 0.66786 - time: 0:00:03.789062
#  Validation:
# Val loss: 0.66642 - time: 0:00:00.667412
# Patient AUC: 0.64505 - Slice AUC: 0.62189
#  Hold out:
# Val loss: 0.69761 - time: 0:00:00.802424
# Patient AUC: 0.53174 - Slice AUC: 0.51973
# Val AUC improved from 0.61087 to 0.64505
#
# Epoch 5/50:
# Train loss: 0.66069 - time: 0:00:03.630458
#  Validation:
# Val loss: 0.66745 - time: 0:00:00.652870
# Patient AUC: 0.65498 - Slice AUC: 0.62901
#  Hold out:
# Val loss: 0.71795 - time: 0:00:00.820494
# Patient AUC: 0.48882 - Slice AUC: 0.49804
# Val AUC improved from 0.64505 to 0.65498
#
# Epoch 6/50:
# Train loss: 0.65316 - time: 0:00:03.745030
#  Validation:
# Val loss: 0.65676 - time: 0:00:00.699606
# Patient AUC: 0.67244 - Slice AUC: 0.64761
#  Hold out:
# Val loss: 0.70463 - time: 0:00:00.819131
# Patient AUC: 0.47899 - Slice AUC: 0.50481
# Val AUC improved from 0.65498 to 0.67244
#
# Epoch 7/50:
# Train loss: 0.64591 - time: 0:00:04.024719
#  Validation:
# Val loss: 0.64773 - time: 0:00:00.975608
# Patient AUC: 0.71240 - Slice AUC: 0.66516
#  Hold out:
# Val loss: 0.73152 - time: 0:00:00.830473
# Patient AUC: 0.47481 - Slice AUC: 0.49029
# Val AUC improved from 0.67244 to 0.71240
#
# Epoch 8/50:
# Train loss: 0.63663 - time: 0:00:03.779157
#  Validation:
# Val loss: 0.63815 - time: 0:00:00.668247
# Patient AUC: 0.71630 - Slice AUC: 0.68064
#  Hold out:
# Val loss: 0.72191 - time: 0:00:00.824287
# Patient AUC: 0.49806 - Slice AUC: 0.52301
# Val AUC improved from 0.71240 to 0.71630
#
# Epoch 9/50:
# Train loss: 0.62743 - time: 0:00:03.954400
#  Validation:
# Val loss: 0.63657 - time: 0:00:00.663041
# Patient AUC: 0.75143 - Slice AUC: 0.69036
#  Hold out:
# Val loss: 0.75546 - time: 0:00:00.813362
# Patient AUC: 0.42116 - Slice AUC: 0.46685
# Val AUC improved from 0.71630 to 0.75143
#
# Epoch 10/50:
# Train loss: 0.61377 - time: 0:00:03.705320
#  Validation:
# Val loss: 0.61755 - time: 0:00:00.726194
# Patient AUC: 0.76093 - Slice AUC: 0.71594
#  Hold out:
# Val loss: 0.72662 - time: 0:00:00.800173
# Patient AUC: 0.50224 - Slice AUC: 0.52341
# Val AUC improved from 0.75143 to 0.76093
#
# Epoch 11/50:
# Train loss: 0.60143 - time: 0:00:03.592046
#  Validation:
# Val loss: 0.60616 - time: 0:00:00.654670
# Patient AUC: 0.79518 - Slice AUC: 0.73251
#  Hold out:
# Val loss: 0.75674 - time: 0:00:00.816180
# Patient AUC: 0.47154 - Slice AUC: 0.49461
# Val AUC improved from 0.76093 to 0.79518
#
# Epoch 12/50:
# Train loss: 0.59163 - time: 0:00:03.609667
#  Validation:
# Val loss: 0.60541 - time: 0:00:00.874905
# Patient AUC: 0.78892 - Slice AUC: 0.73240
#  Hold out:
# Val loss: 0.75429 - time: 0:00:00.816630
# Patient AUC: 0.49717 - Slice AUC: 0.52509
#
# Epoch 13/50:
# Train loss: 0.57945 - time: 0:00:03.860569
#  Validation:
# Val loss: 0.59166 - time: 0:00:00.996835
# Patient AUC: 0.82142 - Slice AUC: 0.74913
#  Hold out:
# Val loss: 0.76849 - time: 0:00:00.951368
# Patient AUC: 0.48376 - Slice AUC: 0.51924
# Val AUC improved from 0.79518 to 0.82142
#
# Epoch 14/50:
# Train loss: 0.57020 - time: 0:00:03.625904
#  Validation:
# Val loss: 0.58490 - time: 0:00:00.884973
# Patient AUC: 0.82343 - Slice AUC: 0.75423
#  Hold out:
# Val loss: 0.75283 - time: 0:00:00.811123
# Patient AUC: 0.52817 - Slice AUC: 0.53829
# Val AUC improved from 0.82142 to 0.82343
#
# Epoch 15/50:
# Train loss: 0.55330 - time: 0:00:03.956205
#  Validation:
# Val loss: 0.58037 - time: 0:00:00.664027
# Patient AUC: 0.84338 - Slice AUC: 0.75978
#  Hold out:
# Val loss: 0.81845 - time: 0:00:00.813043
# Patient AUC: 0.46170 - Slice AUC: 0.49333
# Val AUC improved from 0.82343 to 0.84338
#
# Epoch 16/50:
# Train loss: 0.54710 - time: 0:00:03.620682
#  Validation:
# Val loss: 0.57381 - time: 0:00:00.897277
# Patient AUC: 0.84713 - Slice AUC: 0.76247
#  Hold out:
# Val loss: 0.81920 - time: 0:00:00.803567
# Patient AUC: 0.50671 - Slice AUC: 0.51994
# Val AUC improved from 0.84338 to 0.84713
#
# Epoch 17/50:
# Train loss: 0.53861 - time: 0:00:03.602937
#  Validation:
# Val loss: 0.56986 - time: 0:00:00.660250
# Patient AUC: 0.85764 - Slice AUC: 0.76777
#  Hold out:
# Val loss: 0.82660 - time: 0:00:00.802509
# Patient AUC: 0.48554 - Slice AUC: 0.50144
# Val AUC improved from 0.84713 to 0.85764
#
# Epoch 18/50:
# Train loss: 0.53032 - time: 0:00:03.631780
#  Validation:
# Val loss: 0.57586 - time: 0:00:00.658149
# Patient AUC: 0.84755 - Slice AUC: 0.76454
#  Hold out:
# Val loss: 0.84856 - time: 0:00:01.066845
# Patient AUC: 0.50820 - Slice AUC: 0.51177
#
# Epoch 19/50:
# Train loss: 0.52213 - time: 0:00:03.814992
#  Validation:
# Val loss: 0.55931 - time: 0:00:00.947395
# Patient AUC: 0.86243 - Slice AUC: 0.77824
#  Hold out:
# Val loss: 0.81466 - time: 0:00:01.120015
# Patient AUC: 0.50402 - Slice AUC: 0.51619
# Val AUC improved from 0.85764 to 0.86243
#
# Epoch 20/50:
# Train loss: 0.51782 - time: 0:00:03.589202
#  Validation:
# Val loss: 0.54910 - time: 0:00:00.823955
# Patient AUC: 0.87411 - Slice AUC: 0.78918
#  Hold out:
# Val loss: 0.83182 - time: 0:00:00.918751
# Patient AUC: 0.51267 - Slice AUC: 0.51926
# Val AUC improved from 0.86243 to 0.87411
#
# Epoch 21/50:
# Train loss: 0.50738 - time: 0:00:03.862371
#  Validation:
# Val loss: 0.54608 - time: 0:00:00.663944
# Patient AUC: 0.88600 - Slice AUC: 0.79184
#  Hold out:
# Val loss: 0.84574 - time: 0:00:00.816655
# Patient AUC: 0.48465 - Slice AUC: 0.49955
# Val AUC improved from 0.87411 to 0.88600
#
# Epoch 22/50:
# Train loss: 0.50134 - time: 0:00:03.657199
#  Validation:
# Val loss: 0.54200 - time: 0:00:00.736134
# Patient AUC: 0.88793 - Slice AUC: 0.79289
#  Hold out:
# Val loss: 0.84950 - time: 0:00:00.945081
# Patient AUC: 0.49151 - Slice AUC: 0.50464
# Val AUC improved from 0.88600 to 0.88793
#
# Epoch 23/50:
# Train loss: 0.49053 - time: 0:00:03.582207
#  Validation:
# Val loss: 0.54049 - time: 0:00:00.665854
# Patient AUC: 0.89199 - Slice AUC: 0.80009
#  Hold out:
# Val loss: 0.88468 - time: 0:00:00.821860
# Patient AUC: 0.49657 - Slice AUC: 0.50799
# Val AUC improved from 0.88793 to 0.89199
#
# Epoch 24/50:
# Train loss: 0.48300 - time: 0:00:03.578789
#  Validation:
# Val loss: 0.53856 - time: 0:00:00.669170
# Patient AUC: 0.88986 - Slice AUC: 0.79934
#  Hold out:
# Val loss: 0.90444 - time: 0:00:00.990642
# Patient AUC: 0.48912 - Slice AUC: 0.50518
#
# Epoch 25/50:
# Train loss: 0.47478 - time: 0:00:03.651809
#  Validation:
# Val loss: 0.53464 - time: 0:00:00.931507
# Patient AUC: 0.88847 - Slice AUC: 0.80623
#  Hold out:
# Val loss: 0.90330 - time: 0:00:01.133234
# Patient AUC: 0.48346 - Slice AUC: 0.50513
#
# Epoch 26/50:
# Train loss: 0.47193 - time: 0:00:03.767741
#  Validation:
# Val loss: 0.54162 - time: 0:00:00.664723
# Patient AUC: 0.89427 - Slice AUC: 0.80313
#  Hold out:
# Val loss: 0.90588 - time: 0:00:01.055389
# Patient AUC: 0.50849 - Slice AUC: 0.50454
# Val AUC improved from 0.89199 to 0.89427
#
# Epoch 27/50:
# Train loss: 0.45814 - time: 0:00:03.982074
#  Validation:
# Val loss: 0.53172 - time: 0:00:00.690973
# Patient AUC: 0.89802 - Slice AUC: 0.80871
#  Hold out:
# Val loss: 0.92470 - time: 0:00:00.856860
# Patient AUC: 0.51297 - Slice AUC: 0.51377
# Val AUC improved from 0.89427 to 0.89802
#
# Epoch 28/50:
# Train loss: 0.45877 - time: 0:00:03.628095
#  Validation:
# Val loss: 0.53830 - time: 0:00:00.663793
# Patient AUC: 0.89413 - Slice AUC: 0.80341
#  Hold out:
# Val loss: 0.95749 - time: 0:00:01.014934
# Patient AUC: 0.46647 - Slice AUC: 0.48915
#
# Epoch 29/50:
# Train loss: 0.45087 - time: 0:00:03.596578
#  Validation:
# Val loss: 0.53771 - time: 0:00:00.654058
# Patient AUC: 0.89346 - Slice AUC: 0.80936
#  Hold out:
# Val loss: 0.92589 - time: 0:00:00.832323
# Patient AUC: 0.52936 - Slice AUC: 0.52236
#
# Epoch 30/50:
# Train loss: 0.45217 - time: 0:00:03.602543
#  Validation:
# Val loss: 0.51758 - time: 0:00:00.666447
# Patient AUC: 0.89409 - Slice AUC: 0.82023
#  Hold out:
# Val loss: 0.89373 - time: 0:00:00.812519
# Patient AUC: 0.56125 - Slice AUC: 0.54001
#
# Epoch 31/50:
# Train loss: 0.44654 - time: 0:00:03.844621
#  Validation:
# Val loss: 0.52859 - time: 0:00:00.693731
# Patient AUC: 0.89037 - Slice AUC: 0.81802
#  Hold out:
# Val loss: 0.95009 - time: 0:00:01.138318
# Patient AUC: 0.52280 - Slice AUC: 0.51627
# Early stopping. Best model is epoch 27
# Val loss: 0.53172, Val auc: 0.89802
# Saving model...
# ### Train ['T1wCE'] on fold 3: ###
# 100%|██████████| 466/466 [00:01<00:00, 367.28it/s]
# Loading dataset: 100%|██████████| 10393/10393 [00:30<00:00, 336.34it/s]
# 100%|██████████| 466/466 [00:01<00:00, 430.76it/s]
# Loading dataset: 100%|██████████| 2599/2599 [00:07<00:00, 340.66it/s]
# 100%|██████████| 116/116 [00:00<00:00, 477.18it/s]
# Loading dataset: 100%|██████████| 3204/3204 [00:09<00:00, 334.55it/s]
# Epoch 1/50:
# Train loss: 0.68188 - time: 0:00:03.681989
#  Validation:
# Val loss: 0.67805 - time: 0:00:00.680517
# Patient AUC: 0.60439 - Slice AUC: 0.61067
#  Hold out:
# Val loss: 0.70457 - time: 0:00:00.786390
# Patient AUC: 0.50045 - Slice AUC: 0.53603
# Val AUC improved from -inf to 0.60439
#
# Epoch 2/50:
# Train loss: 0.67106 - time: 0:00:03.651992
#  Validation:
# Val loss: 0.66368 - time: 0:00:00.764350
# Patient AUC: 0.62988 - Slice AUC: 0.63710
#  Hold out:
# Val loss: 0.71838 - time: 0:00:00.893962
# Patient AUC: 0.51684 - Slice AUC: 0.50864
# Val AUC improved from 0.60439 to 0.62988
#
# Epoch 3/50:
# Train loss: 0.66576 - time: 0:00:03.743775
#  Validation:
# Val loss: 0.65781 - time: 0:00:00.877862
# Patient AUC: 0.64524 - Slice AUC: 0.64701
#  Hold out:
# Val loss: 0.72217 - time: 0:00:01.116984
# Patient AUC: 0.49598 - Slice AUC: 0.51070
# Val AUC improved from 0.62988 to 0.64524
#
# Epoch 4/50:
# Train loss: 0.65841 - time: 0:00:03.865525
#  Validation:
# Val loss: 0.64926 - time: 0:00:00.895567
# Patient AUC: 0.66984 - Slice AUC: 0.67322
#  Hold out:
# Val loss: 0.72751 - time: 0:00:00.790863
# Patient AUC: 0.47690 - Slice AUC: 0.49088
# Val AUC improved from 0.64524 to 0.66984
#
# Epoch 5/50:
# Train loss: 0.64630 - time: 0:00:04.055478
#  Validation:
# Val loss: 0.65554 - time: 0:00:00.697652
# Patient AUC: 0.66984 - Slice AUC: 0.66319
#  Hold out:
# Val loss: 0.73256 - time: 0:00:00.841581
# Patient AUC: 0.40864 - Slice AUC: 0.45988
#
# Epoch 6/50:
# Train loss: 0.63645 - time: 0:00:03.776459
#  Validation:
# Val loss: 0.63323 - time: 0:00:00.938803
# Patient AUC: 0.70134 - Slice AUC: 0.69478
#  Hold out:
# Val loss: 0.78080 - time: 0:00:00.805140
# Patient AUC: 0.47422 - Slice AUC: 0.48919
# Val AUC improved from 0.66984 to 0.70134
#
# Epoch 7/50:
# Train loss: 0.61537 - time: 0:00:03.731529
#  Validation:
# Val loss: 0.61881 - time: 0:00:00.670551
# Patient AUC: 0.74467 - Slice AUC: 0.71224
#  Hold out:
# Val loss: 0.75566 - time: 0:00:00.780895
# Patient AUC: 0.47392 - Slice AUC: 0.48614
# Val AUC improved from 0.70134 to 0.74467
#
# Epoch 8/50:
# Train loss: 0.59711 - time: 0:00:03.634443
#  Validation:
# Val loss: 0.62673 - time: 0:00:00.875324
# Patient AUC: 0.75521 - Slice AUC: 0.73035
#  Hold out:
# Val loss: 0.83846 - time: 0:00:00.821022
# Patient AUC: 0.47809 - Slice AUC: 0.47966
# Val AUC improved from 0.74467 to 0.75521
#
# Epoch 9/50:
# Train loss: 0.57640 - time: 0:00:03.639250
#  Validation:
# Val loss: 0.58626 - time: 0:00:00.807544
# Patient AUC: 0.78154 - Slice AUC: 0.74564
#  Hold out:
# Val loss: 0.84719 - time: 0:00:01.130160
# Patient AUC: 0.42295 - Slice AUC: 0.46146
# Val AUC improved from 0.75521 to 0.78154
#
# Epoch 10/50:
# Train loss: 0.55981 - time: 0:00:03.954062
#  Validation:
# Val loss: 0.57544 - time: 0:00:00.896754
# Patient AUC: 0.80744 - Slice AUC: 0.76071
#  Hold out:
# Val loss: 0.82074 - time: 0:00:00.817284
# Patient AUC: 0.43428 - Slice AUC: 0.46588
# Val AUC improved from 0.78154 to 0.80744
#
# Epoch 11/50:
# Train loss: 0.53565 - time: 0:00:04.023054
#  Validation:
# Val loss: 0.56824 - time: 0:00:00.675508
# Patient AUC: 0.80834 - Slice AUC: 0.76837
#  Hold out:
# Val loss: 0.86686 - time: 0:00:00.787745
# Patient AUC: 0.44054 - Slice AUC: 0.46850
# Val AUC improved from 0.80744 to 0.80834
#
# Epoch 12/50:
# Train loss: 0.51615 - time: 0:00:03.656199
#  Validation:
# Val loss: 0.55469 - time: 0:00:00.881662
# Patient AUC: 0.82326 - Slice AUC: 0.78325
#  Hold out:
# Val loss: 0.87044 - time: 0:00:00.782982
# Patient AUC: 0.45663 - Slice AUC: 0.48376
# Val AUC improved from 0.80834 to 0.82326
#
# Epoch 13/50:
# Train loss: 0.49712 - time: 0:00:03.658642
#  Validation:
# Val loss: 0.55813 - time: 0:00:00.662895
# Patient AUC: 0.82591 - Slice AUC: 0.78282
#  Hold out:
# Val loss: 0.89228 - time: 0:00:00.786272
# Patient AUC: 0.45127 - Slice AUC: 0.49315
# Val AUC improved from 0.82326 to 0.82591
#
# Epoch 14/50:
# Train loss: 0.48100 - time: 0:00:03.649392
#  Validation:
# Val loss: 0.55152 - time: 0:00:00.738585
# Patient AUC: 0.83718 - Slice AUC: 0.79383
#  Hold out:
# Val loss: 0.95012 - time: 0:00:00.912431
# Patient AUC: 0.45365 - Slice AUC: 0.47602
# Val AUC improved from 0.82591 to 0.83718
#
# Epoch 15/50:
# Train loss: 0.46381 - time: 0:00:03.636744
#  Validation:
# Val loss: 0.54185 - time: 0:00:00.661538
# Patient AUC: 0.83206 - Slice AUC: 0.80452
#  Hold out:
# Val loss: 1.00176 - time: 0:00:00.811678
# Patient AUC: 0.46885 - Slice AUC: 0.49340
#
# Epoch 16/50:
# Train loss: 0.44782 - time: 0:00:04.348533
#  Validation:
# Val loss: 0.54423 - time: 0:00:00.821388
# Patient AUC: 0.85502 - Slice AUC: 0.80847
#  Hold out:
# Val loss: 0.98277 - time: 0:00:00.907435
# Patient AUC: 0.45633 - Slice AUC: 0.49312
# Val AUC improved from 0.83718 to 0.85502
#
# Epoch 17/50:
# Train loss: 0.43268 - time: 0:00:04.029654
#  Validation:
# Val loss: 0.52363 - time: 0:00:00.681264
# Patient AUC: 0.85453 - Slice AUC: 0.81569
#  Hold out:
# Val loss: 1.02271 - time: 0:00:00.785555
# Patient AUC: 0.46319 - Slice AUC: 0.49413
#
# Epoch 18/50:
# Train loss: 0.42273 - time: 0:00:03.703042
#  Validation:
# Val loss: 0.54781 - time: 0:00:00.844111
# Patient AUC: 0.85637 - Slice AUC: 0.81184
#  Hold out:
# Val loss: 1.06148 - time: 0:00:00.813208
# Patient AUC: 0.44918 - Slice AUC: 0.48834
# Val AUC improved from 0.85502 to 0.85637
#
# Epoch 19/50:
# Train loss: 0.40789 - time: 0:00:03.674213
#  Validation:
# Val loss: 0.52203 - time: 0:00:00.674065
# Patient AUC: 0.85962 - Slice AUC: 0.82146
#  Hold out:
# Val loss: 1.06450 - time: 0:00:00.780791
# Patient AUC: 0.47243 - Slice AUC: 0.49106
# Val AUC improved from 0.85637 to 0.85962
#
# Epoch 20/50:
# Train loss: 0.39458 - time: 0:00:03.639147
#  Validation:
# Val loss: 0.52557 - time: 0:00:00.667382
# Patient AUC: 0.86509 - Slice AUC: 0.82721
#  Hold out:
# Val loss: 1.16126 - time: 0:00:01.030861
# Patient AUC: 0.46289 - Slice AUC: 0.48316
# Val AUC improved from 0.85962 to 0.86509
#
# Epoch 21/50:
# Train loss: 0.38061 - time: 0:00:03.602741
#  Validation:
# Val loss: 0.51705 - time: 0:00:00.654142
# Patient AUC: 0.86673 - Slice AUC: 0.82931
#  Hold out:
# Val loss: 1.08055 - time: 0:00:00.803138
# Patient AUC: 0.49091 - Slice AUC: 0.50623
# Val AUC improved from 0.86509 to 0.86673
#
# Epoch 22/50:
# Train loss: 0.36634 - time: 0:00:04.192127
#  Validation:
# Val loss: 0.53899 - time: 0:00:01.007870
# Patient AUC: 0.85917 - Slice AUC: 0.82712
#  Hold out:
# Val loss: 1.20304 - time: 0:00:00.948760
# Patient AUC: 0.48018 - Slice AUC: 0.49723
#
# Epoch 23/50:
# Train loss: 0.36497 - time: 0:00:03.969618
#  Validation:
# Val loss: 0.54133 - time: 0:00:00.661365
# Patient AUC: 0.87279 - Slice AUC: 0.82221
#  Hold out:
# Val loss: 1.14306 - time: 0:00:00.765090
# Patient AUC: 0.50760 - Slice AUC: 0.51922
# Val AUC improved from 0.86673 to 0.87279
#
# Epoch 24/50:
# Train loss: 0.34769 - time: 0:00:03.623475
#  Validation:
# Val loss: 0.54038 - time: 0:00:00.661557
# Patient AUC: 0.87796 - Slice AUC: 0.83708
#  Hold out:
# Val loss: 1.24220 - time: 0:00:00.996438
# Patient AUC: 0.48972 - Slice AUC: 0.50888
# Val AUC improved from 0.87279 to 0.87796
#
# Epoch 25/50:
# Train loss: 0.34575 - time: 0:00:03.610420
#  Validation:
# Val loss: 0.52162 - time: 0:00:00.673135
# Patient AUC: 0.87713 - Slice AUC: 0.84304
#  Hold out:
# Val loss: 1.27514 - time: 0:00:00.776227
# Patient AUC: 0.46766 - Slice AUC: 0.50267
#
# Epoch 26/50:
# Train loss: 0.32950 - time: 0:00:03.602533
#  Validation:
# Val loss: 0.51577 - time: 0:00:00.675001
# Patient AUC: 0.89224 - Slice AUC: 0.84306
#  Hold out:
# Val loss: 1.24312 - time: 0:00:00.912726
# Patient AUC: 0.49091 - Slice AUC: 0.50873
# Val AUC improved from 0.87796 to 0.89224
#
# Epoch 27/50:
# Train loss: 0.33101 - time: 0:00:03.658594
#  Validation:
# Val loss: 0.51422 - time: 0:00:00.663849
# Patient AUC: 0.88977 - Slice AUC: 0.84271
#  Hold out:
# Val loss: 1.22740 - time: 0:00:00.772004
# Patient AUC: 0.51028 - Slice AUC: 0.51618
#
# Epoch 28/50:
# Train loss: 0.31238 - time: 0:00:03.814459
#  Validation:
# Val loss: 0.51735 - time: 0:00:00.904140
# Patient AUC: 0.89105 - Slice AUC: 0.84937
#  Hold out:
# Val loss: 1.33881 - time: 0:00:01.278892
# Patient AUC: 0.49270 - Slice AUC: 0.51652
#
# Epoch 29/50:
# Train loss: 0.30726 - time: 0:00:04.325472
#  Validation:
# Val loss: 0.54196 - time: 0:00:00.660195
# Patient AUC: 0.89116 - Slice AUC: 0.84472
#  Hold out:
# Val loss: 1.37089 - time: 0:00:00.779969
# Patient AUC: 0.48614 - Slice AUC: 0.50180
#
# Epoch 30/50:
# Train loss: 0.30584 - time: 0:00:03.598053
#  Validation:
# Val loss: 0.50364 - time: 0:00:00.660185
# Patient AUC: 0.89100 - Slice AUC: 0.85299
#  Hold out:
# Val loss: 1.33810 - time: 0:00:01.230818
# Patient AUC: 0.44322 - Slice AUC: 0.49017
# Early stopping. Best model is epoch 26
# Val loss: 0.51577, Val auc: 0.89224
# Saving model...
# ### Train ['T1wCE'] on fold 4: ###
# 100%|██████████| 466/466 [00:01<00:00, 460.95it/s]
# Loading dataset: 100%|██████████| 10430/10430 [00:31<00:00, 331.21it/s]
# 100%|██████████| 466/466 [00:00<00:00, 536.39it/s]
# Loading dataset: 100%|██████████| 2608/2608 [00:07<00:00, 337.93it/s]
# 100%|██████████| 116/116 [00:00<00:00, 470.45it/s]
# Loading dataset: 100%|██████████| 3158/3158 [00:09<00:00, 338.27it/s]
# Epoch 1/50:
# Train loss: 0.68420 - time: 0:00:03.787243
#  Validation:
# Val loss: 0.67861 - time: 0:00:00.697848
# Patient AUC: 0.61644 - Slice AUC: 0.61180
#  Hold out:
# Val loss: 0.68934 - time: 0:00:00.800263
# Patient AUC: 0.54456 - Slice AUC: 0.55619
# Val AUC improved from -inf to 0.61644
#
# Epoch 2/50:
# Train loss: 0.67509 - time: 0:00:05.119620
#  Validation:
# Val loss: 0.66888 - time: 0:00:00.669850
# Patient AUC: 0.62942 - Slice AUC: 0.62235
#  Hold out:
# Val loss: 0.70112 - time: 0:00:00.801106
# Patient AUC: 0.53443 - Slice AUC: 0.54192
# Val AUC improved from 0.61644 to 0.62942
#
# Epoch 3/50:
# Train loss: 0.66896 - time: 0:00:03.788467
#  Validation:
# Val loss: 0.67112 - time: 0:00:00.672243
# Patient AUC: 0.64997 - Slice AUC: 0.63016
#  Hold out:
# Val loss: 0.69995 - time: 0:00:00.766972
# Patient AUC: 0.53472 - Slice AUC: 0.54224
# Val AUC improved from 0.62942 to 0.64997
#
# Epoch 4/50:
# Train loss: 0.65556 - time: 0:00:03.648032
#  Validation:
# Val loss: 0.66622 - time: 0:00:00.667194
# Patient AUC: 0.64118 - Slice AUC: 0.62655
#  Hold out:
# Val loss: 0.73409 - time: 0:00:00.799377
# Patient AUC: 0.52727 - Slice AUC: 0.52014
#
# Epoch 5/50:
# Train loss: 0.64431 - time: 0:00:03.810033
#  Validation:
# Val loss: 0.65020 - time: 0:00:00.686725
# Patient AUC: 0.67763 - Slice AUC: 0.65677
#  Hold out:
# Val loss: 0.71925 - time: 0:00:00.769982
# Patient AUC: 0.55440 - Slice AUC: 0.52489
# Val AUC improved from 0.64997 to 0.67763
#
# Epoch 6/50:
# Train loss: 0.63178 - time: 0:00:03.657299
#  Validation:
# Val loss: 0.64268 - time: 0:00:00.655907
# Patient AUC: 0.69241 - Slice AUC: 0.66154
#  Hold out:
# Val loss: 0.74672 - time: 0:00:00.794519
# Patient AUC: 0.53085 - Slice AUC: 0.49285
# Val AUC improved from 0.67763 to 0.69241
#
# Epoch 7/50:
# Train loss: 0.61793 - time: 0:00:03.748237
#  Validation:
# Val loss: 0.63249 - time: 0:00:00.800150
# Patient AUC: 0.69967 - Slice AUC: 0.68198
#  Hold out:
# Val loss: 0.77628 - time: 0:00:00.767745
# Patient AUC: 0.52101 - Slice AUC: 0.48893
# Val AUC improved from 0.69241 to 0.69967
#
# Epoch 8/50:
# Train loss: 0.60102 - time: 0:00:04.770762
#  Validation:
# Val loss: 0.63077 - time: 0:00:00.935792
# Patient AUC: 0.70584 - Slice AUC: 0.69279
#  Hold out:
# Val loss: 0.81806 - time: 0:00:01.096569
# Patient AUC: 0.53592 - Slice AUC: 0.51517
# Val AUC improved from 0.69967 to 0.70584
#
# Epoch 9/50:
# Train loss: 0.58937 - time: 0:00:03.812336
#  Validation:
# Val loss: 0.61636 - time: 0:00:00.690098
# Patient AUC: 0.75118 - Slice AUC: 0.70101
#  Hold out:
# Val loss: 0.79880 - time: 0:00:00.780301
# Patient AUC: 0.50760 - Slice AUC: 0.48047
# Val AUC improved from 0.70584 to 0.75118
#
# Epoch 10/50:
# Train loss: 0.57154 - time: 0:00:03.654629
#  Validation:
# Val loss: 0.60512 - time: 0:00:00.669576
# Patient AUC: 0.76590 - Slice AUC: 0.72060
#  Hold out:
# Val loss: 0.82121 - time: 0:00:00.787732
# Patient AUC: 0.51475 - Slice AUC: 0.47703
# Val AUC improved from 0.75118 to 0.76590
#
# Epoch 11/50:
# Train loss: 0.55009 - time: 0:00:03.795217
#  Validation:
# Val loss: 0.61332 - time: 0:00:00.668706
# Patient AUC: 0.78248 - Slice AUC: 0.72246
#  Hold out:
# Val loss: 0.87610 - time: 0:00:00.777811
# Patient AUC: 0.53592 - Slice AUC: 0.48244
# Val AUC improved from 0.76590 to 0.78248
#
# Epoch 12/50:
# Train loss: 0.54069 - time: 0:00:03.647128
#  Validation:
# Val loss: 0.58194 - time: 0:00:00.691148
# Patient AUC: 0.78376 - Slice AUC: 0.75091
#  Hold out:
# Val loss: 0.86819 - time: 0:00:00.795977
# Patient AUC: 0.53830 - Slice AUC: 0.49259
# Val AUC improved from 0.78248 to 0.78376
#
# Epoch 13/50:
# Train loss: 0.51838 - time: 0:00:03.856220
#  Validation:
# Val loss: 0.58828 - time: 0:00:00.704934
# Patient AUC: 0.79214 - Slice AUC: 0.75485
#  Hold out:
# Val loss: 0.95598 - time: 0:00:00.791207
# Patient AUC: 0.55559 - Slice AUC: 0.50513
# Val AUC improved from 0.78376 to 0.79214
#
# Epoch 14/50:
# Train loss: 0.50329 - time: 0:00:04.174483
#  Validation:
# Val loss: 0.58418 - time: 0:00:00.983301
# Patient AUC: 0.81102 - Slice AUC: 0.76213
#  Hold out:
# Val loss: 0.92386 - time: 0:00:01.152933
# Patient AUC: 0.52876 - Slice AUC: 0.48911
# Val AUC improved from 0.79214 to 0.81102
#
# Epoch 15/50:
# Train loss: 0.49072 - time: 0:00:04.423227
#  Validation:
# Val loss: 0.56134 - time: 0:00:00.698794
# Patient AUC: 0.81019 - Slice AUC: 0.77391
#  Hold out:
# Val loss: 0.94478 - time: 0:00:00.775132
# Patient AUC: 0.52876 - Slice AUC: 0.48697
#
# Epoch 16/50:
# Train loss: 0.47599 - time: 0:00:03.668006
#  Validation:
# Val loss: 0.56647 - time: 0:00:00.694802
# Patient AUC: 0.82244 - Slice AUC: 0.77980
#  Hold out:
# Val loss: 0.94139 - time: 0:00:00.770483
# Patient AUC: 0.56990 - Slice AUC: 0.50628
# Val AUC improved from 0.81102 to 0.82244
#
# Epoch 17/50:
# Train loss: 0.46407 - time: 0:00:03.809367
#  Validation:
# Val loss: 0.55163 - time: 0:00:00.675335
# Patient AUC: 0.82800 - Slice AUC: 0.78894
#  Hold out:
# Val loss: 0.97784 - time: 0:00:00.770020
# Patient AUC: 0.57049 - Slice AUC: 0.50603
# Val AUC improved from 0.82244 to 0.82800
#
# Epoch 18/50:
# Train loss: 0.45056 - time: 0:00:03.652721
#  Validation:
# Val loss: 0.55031 - time: 0:00:00.669387
# Patient AUC: 0.82420 - Slice AUC: 0.79181
#  Hold out:
# Val loss: 0.98924 - time: 0:00:00.784524
# Patient AUC: 0.56364 - Slice AUC: 0.50253
#
# Epoch 19/50:
# Train loss: 0.43660 - time: 0:00:03.778518
#  Validation:
# Val loss: 0.56939 - time: 0:00:00.669072
# Patient AUC: 0.78694 - Slice AUC: 0.78592
#  Hold out:
# Val loss: 1.02977 - time: 0:00:00.783707
# Patient AUC: 0.58152 - Slice AUC: 0.52502
#
# Epoch 20/50:
# Train loss: 0.42691 - time: 0:00:03.990810
#  Validation:
# Val loss: 0.54666 - time: 0:00:00.687154
# Patient AUC: 0.82692 - Slice AUC: 0.79644
#  Hold out:
# Val loss: 1.02747 - time: 0:00:00.848011
# Patient AUC: 0.56185 - Slice AUC: 0.50353
#
# Epoch 21/50:
# Train loss: 0.40705 - time: 0:00:04.708459
#  Validation:
# Val loss: 0.54442 - time: 0:00:00.841355
# Patient AUC: 0.82857 - Slice AUC: 0.80975
#  Hold out:
# Val loss: 1.10324 - time: 0:00:00.811524
# Patient AUC: 0.57765 - Slice AUC: 0.51187
# Val AUC improved from 0.82800 to 0.82857
#
# Epoch 22/50:
# Train loss: 0.40126 - time: 0:00:03.665425
#  Validation:
# Val loss: 0.55197 - time: 0:00:00.673543
# Patient AUC: 0.83128 - Slice AUC: 0.80527
#  Hold out:
# Val loss: 1.14422 - time: 0:00:00.785665
# Patient AUC: 0.54367 - Slice AUC: 0.49319
# Val AUC improved from 0.82857 to 0.83128
#
# Epoch 23/50:
# Train loss: 0.38867 - time: 0:00:03.770572
#  Validation:
# Val loss: 0.55234 - time: 0:00:00.675043
# Patient AUC: 0.82408 - Slice AUC: 0.81093
#  Hold out:
# Val loss: 1.20277 - time: 0:00:00.775582
# Patient AUC: 0.56602 - Slice AUC: 0.51405
#
# Epoch 24/50:
# Train loss: 0.38545 - time: 0:00:03.672066
#  Validation:
# Val loss: 0.54392 - time: 0:00:00.672639
# Patient AUC: 0.83526 - Slice AUC: 0.81601
#  Hold out:
# Val loss: 1.21157 - time: 0:00:00.760969
# Patient AUC: 0.53890 - Slice AUC: 0.49099
# Val AUC improved from 0.83128 to 0.83526
#
# Epoch 25/50:
# Train loss: 0.37370 - time: 0:00:03.803174
#  Validation:
# Val loss: 0.54849 - time: 0:00:00.685690
# Patient AUC: 0.85056 - Slice AUC: 0.81238
#  Hold out:
# Val loss: 1.11523 - time: 0:00:00.779012
# Patient AUC: 0.54069 - Slice AUC: 0.50159
# Val AUC improved from 0.83526 to 0.85056
#
# Epoch 26/50:
# Train loss: 0.36268 - time: 0:00:04.069469
#  Validation:
# Val loss: 0.54480 - time: 0:00:00.673433
# Patient AUC: 0.83575 - Slice AUC: 0.81888
#  Hold out:
# Val loss: 1.23399 - time: 0:00:00.794809
# Patient AUC: 0.55052 - Slice AUC: 0.50418
#
# Epoch 27/50:
# Train loss: 0.35294 - time: 0:00:04.293426
#  Validation:
# Val loss: 0.54307 - time: 0:00:00.902866
# Patient AUC: 0.84039 - Slice AUC: 0.82249
#  Hold out:
# Val loss: 1.25658 - time: 0:00:01.075798
# Patient AUC: 0.56841 - Slice AUC: 0.50632
#
# Epoch 28/50:
# Train loss: 0.34379 - time: 0:00:04.012736
#  Validation:
# Val loss: 0.54103 - time: 0:00:00.669822
# Patient AUC: 0.85062 - Slice AUC: 0.82753
#  Hold out:
# Val loss: 1.25037 - time: 0:00:00.772674
# Patient AUC: 0.56215 - Slice AUC: 0.50959
# Val AUC improved from 0.85056 to 0.85062
#
# Epoch 29/50:
# Train loss: 0.32958 - time: 0:00:03.772637
#  Validation:
# Val loss: 0.55015 - time: 0:00:00.683058
# Patient AUC: 0.85144 - Slice AUC: 0.82693
#  Hold out:
# Val loss: 1.31790 - time: 0:00:00.760475
# Patient AUC: 0.55499 - Slice AUC: 0.49945
# Val AUC improved from 0.85062 to 0.85144
#
# Epoch 30/50:
# Train loss: 0.32372 - time: 0:00:03.595974
#  Validation:
# Val loss: 0.54966 - time: 0:00:00.667137
# Patient AUC: 0.85674 - Slice AUC: 0.83154
#  Hold out:
# Val loss: 1.35385 - time: 0:00:00.763533
# Patient AUC: 0.55499 - Slice AUC: 0.49886
# Val AUC improved from 0.85144 to 0.85674
#
# Epoch 31/50:
# Train loss: 0.31716 - time: 0:00:03.801102
#  Validation:
# Val loss: 0.54968 - time: 0:00:00.681826
# Patient AUC: 0.86587 - Slice AUC: 0.83249
#  Hold out:
# Val loss: 1.31189 - time: 0:00:01.141116
# Patient AUC: 0.58003 - Slice AUC: 0.51548
# Val AUC improved from 0.85674 to 0.86587
#
# Epoch 32/50:
# Train loss: 0.31290 - time: 0:00:03.711188
#  Validation:
# Val loss: 0.56848 - time: 0:00:00.662016
# Patient AUC: 0.85554 - Slice AUC: 0.83186
#  Hold out:
# Val loss: 1.35939 - time: 0:00:00.766826
# Patient AUC: 0.60596 - Slice AUC: 0.52911
#
# Epoch 33/50:
# Train loss: 0.30312 - time: 0:00:03.797513
#  Validation:
# Val loss: 0.56287 - time: 0:00:00.721895
# Patient AUC: 0.86358 - Slice AUC: 0.83058
#  Hold out:
# Val loss: 1.34170 - time: 0:00:00.949150
# Patient AUC: 0.55678 - Slice AUC: 0.50824
#
# Epoch 34/50:
# Train loss: 0.29506 - time: 0:00:04.569900
#  Validation:
# Val loss: 0.55881 - time: 0:00:00.662723
# Patient AUC: 0.85512 - Slice AUC: 0.83349
#  Hold out:
# Val loss: 1.37480 - time: 0:00:00.762525
# Patient AUC: 0.57109 - Slice AUC: 0.51762
#
# Epoch 35/50:
# Train loss: 0.30269 - time: 0:00:03.782513
#  Validation:
# Val loss: 0.56164 - time: 0:00:00.668863
# Patient AUC: 0.84992 - Slice AUC: 0.83155
#  Hold out:
# Val loss: 1.37113 - time: 0:00:00.775050
# Patient AUC: 0.55768 - Slice AUC: 0.50846
# Early stopping. Best model is epoch 31
# Val loss: 0.54968, Val auc: 0.86587
# Saving model...

# %% [markdown]
# ## Evaluate

# %%
metrics = []
results = []
find_weight = lambda x: [w for w in os.listdir() if x in w][0]
weights_paths = [f'{"_".join(mri_types)}_fold{fold}' for fold in range(n_folds)]
weights_paths = [find_weight(x) for x in weights_paths]
for fold, weights_path in enumerate(weights_paths):
    print(f'### Evaluate {mri_types} on fold {fold}: ###')
    _, _, val_holdout_ds = pipeline.prepare_datasets(mri_types=mri_types, 
                                                     fold=fold,
                                                     cache_rate=0.0)
    pipeline.load_model(weights_path)
    val_metric, val_result = pipeline.evaluate(val_holdout_ds, batch_size=batch_size, verbose=True)
    metrics.append(val_metric)
    results.append(val_result)
results = pd.concat(results, ignore_index=True)
mean_auc = np.mean(metrics)
oof_auc = roc_auc_score(results['label'], results['probability'])
print('---')
print(f'{mri_types} holdout result:')
print(' Mean AUC: {:.5f}'.format(mean_auc))
print(' Out-of-fold AUC: {:.5f}'.format(oof_auc))
print('---')
# Out:
# ### Evaluate ['T1wCE'] on fold 0: ###
# 100%|██████████| 465/465 [00:01<00:00, 449.10it/s]
# 100%|██████████| 465/465 [00:00<00:00, 589.32it/s]
# 100%|██████████| 117/117 [00:00<00:00, 500.66it/s]
#  Hold out:
# Val loss: 1.46764 - time: 0:00:06.037797
# Patient AUC: 0.41026 - Slice AUC: 0.44033
# ### Evaluate ['T1wCE'] on fold 1: ###
# 100%|██████████| 465/465 [00:00<00:00, 469.45it/s]
# 100%|██████████| 465/465 [00:00<00:00, 573.59it/s]
# 100%|██████████| 117/117 [00:00<00:00, 575.17it/s]
#  Hold out:
# Val loss: 1.55515 - time: 0:00:05.746653
# Patient AUC: 0.51874 - Slice AUC: 0.50661
# ### Evaluate ['T1wCE'] on fold 2: ###
# 100%|██████████| 466/466 [00:00<00:00, 596.87it/s]
# 100%|██████████| 466/466 [00:00<00:00, 594.94it/s]
# 100%|██████████| 116/116 [00:00<00:00, 590.71it/s]
#  Hold out:
# Val loss: 0.92470 - time: 0:00:06.588217
# Patient AUC: 0.51297 - Slice AUC: 0.51377
# ### Evaluate ['T1wCE'] on fold 3: ###
# 100%|██████████| 466/466 [00:01<00:00, 407.88it/s]
# 100%|██████████| 466/466 [00:01<00:00, 386.76it/s]
# 100%|██████████| 116/116 [00:00<00:00, 421.89it/s]
#  Hold out:
# Val loss: 1.24312 - time: 0:00:07.674981
# Patient AUC: 0.49091 - Slice AUC: 0.50873
# ### Evaluate ['T1wCE'] on fold 4: ###
# 100%|██████████| 466/466 [00:01<00:00, 407.63it/s]
# 100%|██████████| 466/466 [00:01<00:00, 430.19it/s]
# 100%|██████████| 116/116 [00:00<00:00, 449.26it/s]
#  Hold out:
# Val loss: 1.31189 - time: 0:00:06.226836
# Patient AUC: 0.58003 - Slice AUC: 0.51548
# ---
# ['T1wCE'] holdout result:
#  Mean AUC: 0.50258
#  Out-of-fold AUC: 0.50393
# ---

# %% [markdown]
# As we can see, although the validation AUCs are very high (0.8x to 0.9x) for every fold, the holdout AUC is only around 0.5, which is not even better than random guess.

# %% [markdown]
# ## Inference

# %% [markdown]
# Final prediction for the test set is the average of the predictions of all 5 models.

# %%
test_results = []
for fold, weights_path in enumerate(weights_paths):
    print(f'### Inference {mri_types} on fold {fold}: ###')
    test_ds = pipeline.prepare_test_dataset(mri_types=mri_types, cache_rate=0.0)
    pipeline.load_model(weights_path)
    test_result = pipeline.predict(test_ds, batch_size=batch_size, verbose=True)
    test_results.append(test_result)
# Out:
# ### Inference ['T1wCE'] on fold 0: ###
# 100%|██████████| 87/87 [00:02<00:00, 41.24it/s]
# Elapsed time: 0:00:06.860399
# ### Inference ['T1wCE'] on fold 1: ###
# 100%|██████████| 87/87 [00:00<00:00, 523.89it/s]
# Elapsed time: 0:00:04.786158
# ### Inference ['T1wCE'] on fold 2: ###
# 100%|██████████| 87/87 [00:00<00:00, 820.86it/s]
# Elapsed time: 0:00:04.611454
# ### Inference ['T1wCE'] on fold 3: ###
# 100%|██████████| 87/87 [00:00<00:00, 860.81it/s]
# Elapsed time: 0:00:04.934411
# ### Inference ['T1wCE'] on fold 4: ###
# 100%|██████████| 87/87 [00:00<00:00, 871.78it/s]
# Elapsed time: 0:00:04.624844

# %%
prediction = pd.concat([x.set_index('BraTS21ID') for x in test_results], axis=1).mean(axis=1)
prediction = pd.DataFrame(prediction, columns=['MGMT_value']).reset_index()
prediction.to_csv('submission.csv',index=False)
